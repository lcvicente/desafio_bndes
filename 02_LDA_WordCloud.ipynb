# %% [markdown]
# <a href="https://colab.research.google.com/github/lcvicente/desafio_bndes/blob/main/02_LDA_WordCloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Alocação Latente de Dirichlet (LDA) - Análise de tópicos e estudo de termos mais frequentes em:
#
# 1.   Contratos de Banco de Serviços -> https://dadosabertos.bndes.gov.br/group/desestatizacao
#
# 2.   Contratos de Operações de Financiamento não Automáticas ->  https://dadosabertos.bndes.gov.br/dataset/operacoes-financiamento

# %%
# !python -m pip install pyLDAvis==2.1.2
# Out:
# Collecting pyLDAvis==2.1.2
#   Downloading pyLDAvis-2.1.2.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 4.9 MB/s
# Requirement already satisfied: wheel>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (0.37.0)
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (1.19.5)
# Requirement already satisfied: scipy>=0.18.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (1.4.1)
# Requirement already satisfied: pandas>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (1.1.5)
# Requirement already satisfied: joblib>=0.8.4 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (1.0.1)
# Requirement already satisfied: jinja2>=2.7.2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (2.11.3)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (2.7.3)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (3.6.4)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis==2.1.2) (0.16.0)
# Collecting funcy
#   Downloading funcy-1.16-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.7.2->pyLDAvis==2.1.2) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17.0->pyLDAvis==2.1.2) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.17.0->pyLDAvis==2.1.2) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.17.0->pyLDAvis==2.1.2) (1.15.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->pyLDAvis==2.1.2) (1.10.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->pyLDAvis==2.1.2) (8.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pytest->pyLDAvis==2.1.2) (57.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->pyLDAvis==2.1.2) (21.2.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->pyLDAvis==2.1.2) (0.7.1)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->pyLDAvis==2.1.2) (1.4.0)
# Building wheels for collected packages: pyLDAvis
#   Building wheel for pyLDAvis (setup.py) ... done
#   Created wheel for pyLDAvis: filename=pyLDAvis-2.1.2-py2.py3-none-any.whl size=97738 sha256=111ac7a33940c9b2cbaf50ca48ef6d8fc098564fd7c54b2484fd1aca481a6603
#   Stored in directory: /root/.cache/pip/wheels/3b/fb/41/e32e5312da9f440d34c4eff0d2207b46dc9332a7b931ef1e89
# Successfully built pyLDAvis
# Installing collected packages: funcy, pyLDAvis
# Successfully installed funcy-1.16 pyLDAvis-2.1.2

# %%
# Sklearn
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV

# Visualização
import pyLDAvis
import pyLDAvis.sklearn
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# %matplotlib inline


# Outras Bibliotecas
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from operator import itemgetter
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)

np.random.seed(0)

# %% [markdown]
# # Banco de Serviços
#
# ### Estatísticas da atuação do BNDES como Banco de Serviços. https://dadosabertos.bndes.gov.br/group/desestatizacao

# %% [markdown]
# #### Vetorização das palavras para entrada nos modelos de ML

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
workdir_path = '/content/drive/My Drive/BNDES/'
os.chdir(workdir_path)
# Out:
# Mounted at /content/drive

# %%
# Leitura do dataset
df_bs = pd.read_csv('contratos_bs.csv', sep=';', encoding='UTF-8')
corpus_bs = df_bs.texto

# %%
# Vetorização de palavras - TF-IDF
vectorizer_bs = TfidfVectorizer(analyzer='word',       
                             lowercase=True,                   # converter todas as palavras em minúsculas
                             token_pattern='[a-zA-Z0-9]{3,}',  # num chars > 3 - para ser qualificado como token
                             ngram_range = (2,3),              # uni, bi e trigrams
                             max_features=300
                            )

data_vectorized_bs = vectorizer_bs.fit_transform(corpus_bs)

# %% [markdown]
# #### Utilização de GridSearch para encontrar melhor modelo LDA

# %%
# Parâmetros de busca
search_params = {'n_components': [3, 5, 10, 15], 'learning_decay': [.3, .5, .7, .9]}

# Inicializa o modelo
lda = LatentDirichletAllocation()

# Inicializa Grid Search Class
model_bs = GridSearchCV(lda, param_grid=search_params)

# Faz a Grid Search
model_bs.fit(data_vectorized_bs)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=LatentDirichletAllocation(batch_size=128,
#                                                  doc_topic_prior=None,
#                                                  evaluate_every=-1,
#                                                  learning_decay=0.7,
#                                                  learning_method='batch',
#                                                  learning_offset=10.0,
#                                                  max_doc_update_iter=100,
#                                                  max_iter=10,
#                                                  mean_change_tol=0.001,
#                                                  n_components=10, n_jobs=None,
#                                                  perp_tol=0.1,
#                                                  random_state=None,
#                                                  topic_word_prior=None,
#                                                  total_samples=1000000.0,
#                                                  verbose=0),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_decay': [0.3, 0.5, 0.7, 0.9],
#                          'n_components': [3, 5, 10, 15]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %% [markdown]
# #### Escolher o "melhor" modelo

# %%
# Melhor modelo
best_lda_model_bs = model_bs.best_estimator_

# Hiperparâmetros do modelo
print("Melhores parâmetros: ", model_bs.best_params_)

# probabilidade logarítmica
print("Melhor score de probabilidade logarítmica: ", model_bs.best_score_)

# Perplexidade
print("Perplexidade do modelo: ", best_lda_model_bs.perplexity(data_vectorized_bs))

# Utilizar o melhor modelo
lda_output_bs = best_lda_model_bs.transform(data_vectorized_bs)
# Out:
# Melhores parâmetros:  {'learning_decay': 0.5, 'n_components': 3}
# Melhor score de probabilidade logarítmica:  -285.3791110529774
# Perplexidade do modelo:  909.1453092437403

# %% [markdown]
# #### Visualizar o modelo LDA com o pyLDAvis

# %%
# Visualização via pyLDAvis
pyLDAvis.enable_notebook() 
panel = pyLDAvis.sklearn.prepare(best_lda_model_bs, data_vectorized_bs, vectorizer_bs, mds='tsne')
pyLDAvis.save_html(panel, 'lda_bs.html') 
pyLDAvis.display(panel)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el641403261172164648155755105"></div>
# <script type="text/javascript">
#
# var ldavis_el641403261172164648155755105_data = {"mdsDat": {"x": [-1015.7005615234375, -387.9960021972656, -2184.74560546875], "y": [1338.981201171875, -373.316162109375, -60.565799713134766], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [42.119540522645124, 31.41853734571496, 26.461922131639938]}, "tinfo": {"Term": ["fornecimento agua", "esgotamento sanitario", "agua esgotamento", "agua esgotamento sanitario", "fornecimento agua esgotamento", "estruturacao participacao privada", "estruturacao participacao", "especializados estruturacao participacao", "participacao privada", "participacao privada visando", "privada visando", "esgotamento sanitario relativamente", "relativamente estado", "privada visando universalizacao", "visando universalizacao fornecimento", "sanitario relativamente estado", "universalizacao fornecimento", "universalizacao fornecimento agua", "visando universalizacao", "sanitario relativamente", "energia amazonas", "companhia energetica", "contratacao especializados estruturacao", "especializados estruturacao", "agua esgoto", "companhia saneamento", "contratacao especializados", "estruturacao parceria publico", "estruturacao parceria", "eficientizacao expansao operacao", "parceria publico privada", "publico privada", "estruturacao parceria", "estruturacao parceria publico", "expansao operacao", "expansao operacao manutencao", "iluminacao publica", "infraestrutura rede", "manutencao infraestrutura", "manutencao infraestrutura rede", "modernizacao eficientizacao", "modernizacao eficientizacao expansao", "operacao manutencao", "operacao manutencao infraestrutura", "parceria publico", "eficientizacao expansao", "eficientizacao expansao operacao", "rede iluminacao publica", "rede iluminacao", "infraestrutura rede iluminacao", "iluminacao publica municipio", "publica municipio", "contratacao estruturacao", "contratacao estruturacao parceria", "destinada modernizacao", "privada destinada", "publico privada destinada", "destinada modernizacao eficientizacao", "privada destinada modernizacao", "especializados estruturacao parceria", "fornecimento agua esgotamento", "agua esgotamento sanitario", "esgotamento sanitario", "agua esgotamento", "fornecimento agua", "estruturacao participacao privada", "universalizacao fornecimento", "sanitario relativamente", "sanitario relativamente estado", "relativamente estado", "especializados estruturacao participacao", "esgotamento sanitario relativamente", "privada visando universalizacao", "privada visando", "universalizacao fornecimento agua", "participacao privada", "visando universalizacao fornecimento", "visando universalizacao", "estruturacao participacao", "participacao privada visando", "agua esgoto", "companhia saneamento", "estado amapa", "contratacao especializados estruturacao", "estado alagoas", "especializados estruturacao", "especificacoes constantes", "amapa associada transferencia", "estado amapa associada", "amapa servico especificacoes", "contratacao especializados", "eletrica estado amapa", "controle companhia", "transferencia controle", "distribuicao energia eletrica", "associada transferencia controle", "amapa servico", "energia eletrica", "amapa associada", "distribuicao energia", "energia amazonas", "companhia energetica", "desestatizacao companhia", "energetica alagoas", "eletricas rondonia ceron", "eletricidade acre", "eletricidade acre eletroacre", "eletroacre centrais", "eletroacre centrais eletricas", "energetica alagoas ceal", "distribuidora energia", "energetica piaui", "energetica piaui cepisa", "energia amazonas distribuidora", "vista energia", "piaui cepisa", "eletricas rondonia", "vista energia amazonas", "rondonia ceron vista", "companhia energetica piaui", "companhia eletricidade acre", "ceron vista energia", "ceron vista", "centrais eletricas rondonia", "centrais eletricas", "ceal companhia eletricidade", "ceal companhia", "amazonas distribuidora energia", "amazonas distribuidora", "alagoas ceal companhia", "prestacao servico", "servico e ...

# %% [markdown]
# #### WordCloud com as 30 expressões (ngram) mais frequentes por tópico

# %%
# Wordcloud
tf_feature_names_bs = vectorizer_bs.get_feature_names()

fig = plt.figure(figsize=(25,20))
for i in range(len(best_lda_model_bs.components_)):
    topic = best_lda_model_bs.components_[i]
    tupleList = [(tf_feature_names_bs[i], int(topic[i]/topic.sum()*10000)) for i in range(len(topic))]
    ax = fig.add_subplot(3,3,i+1)
    wordcloud = WordCloud(max_words=30).generate_from_frequencies(dict(tupleList))
    ax.imshow(wordcloud)
    ax.set_title('Tópico n°{}' .format(i))
    ax.axis('off');

# %% [markdown]
# # Operações de Financiamento não Automáticas
#
# ##### Dados detalhados das condições das operações de financiamento contratadas, incluindo condições de financiamento, porte do cliente e produto contratado. https://dadosabertos.bndes.gov.br/dataset/operacoes-financiamento

# %% [markdown]
# #### Vetorização das palavras para entrada nos modelos de ML

# %%
# Leitura do dataset
df_ofna = pd.read_csv('contratos_ofna.csv', sep=';', encoding='UTF-8')
corpus_ofna = df_ofna.descricao_do_projeto

# %%
# Vetorização de palavras - TF-IDF
vectorizer_ofna = TfidfVectorizer(analyzer='word',       
                             lowercase=True,                   # converter todas as palavras em minúsculas
                             token_pattern='[a-zA-Z0-9]{3,}',  # num chars > 3 - para ser qualificado como token
                             ngram_range = (1,3),              # uni, bi e trigrams
                             max_features=300
                            )
data_vectorized_ofna = vectorizer_ofna.fit_transform(corpus_ofna)

# %% [markdown]
# #### Utilização de GridSearch para encontrar melhor modelo LDA

# %%
# Parâmetros de busca
search_params = {'n_components': [3, 5, 10, 15], 'learning_decay': [.3, .5, .7, .9]}

# Inicializa o modelo
lda = LatentDirichletAllocation()

# Inicializa Grid Search Class
model_ofna = GridSearchCV(lda, param_grid=search_params)

# Faz a Grid Search
model_ofna.fit(data_vectorized_ofna)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=LatentDirichletAllocation(batch_size=128,
#                                                  doc_topic_prior=None,
#                                                  evaluate_every=-1,
#                                                  learning_decay=0.7,
#                                                  learning_method='batch',
#                                                  learning_offset=10.0,
#                                                  max_doc_update_iter=100,
#                                                  max_iter=10,
#                                                  mean_change_tol=0.001,
#                                                  n_components=10, n_jobs=None,
#                                                  perp_tol=0.1,
#                                                  random_state=None,
#                                                  topic_word_prior=None,
#                                                  total_samples=1000000.0,
#                                                  verbose=0),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_decay': [0.3, 0.5, 0.7, 0.9],
#                          'n_components': [3, 5, 10, 15]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %% [markdown]
# #### Escolher o "melhor" modelo

# %%
# Melhor modelo
best_lda_model_ofna = model_ofna.best_estimator_

# Hiperparâmetros do modelo
print("Melhores parâmetros: ", model_ofna.best_params_)

# probabilidade logarítmica
print("Melhor score de probabilidade logarítmica: ", model_ofna.best_score_)

# Perplexidade
print("Perplexidade do modelo: ", best_lda_model_ofna.perplexity(data_vectorized_ofna))

# Utilizar o melhor modelo
lda_output_ofna = best_lda_model_ofna.transform(data_vectorized_ofna)
# Out:
# Melhores parâmetros:  {'learning_decay': 0.7, 'n_components': 3}
# Melhor score de probabilidade logarítmica:  -63445.30089245118
# Perplexidade do modelo:  256.30202599091126

# %% [markdown]
# #### Visualizar o modelo LDA com o pyLDAvis

# %%
# Visualização via pyLDAvis
pyLDAvis.enable_notebook() 
panel = pyLDAvis.sklearn.prepare(best_lda_model_ofna, data_vectorized_ofna, vectorizer_ofna, mds='tsne')
pyLDAvis.save_html(panel, 'lda_ofna.html') 
pyLDAvis.display(panel)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el641403260541023526073894009"></div>
# <script type="text/javascript">
#
# var ldavis_el641403260541023526073894009_data = {"mdsDat": {"x": [-1015.7005615234375, -387.9960021972656, -2184.74560546875], "y": [1338.981201171875, -373.316162109375, -60.565799713134766], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [35.51034742815482, 33.18783289340247, 31.301819678442698]}, "tinfo": {"Term": ["capacidade", "instalada", "capacidade instalada", "desenvolvimento", "cana", "acucar", "eletrica", "investimentos", "construcao", "parque", "capital", "tipo", "leilao", "eolico", "energia eletrica", "implantacao", "estaleiro", "objeto", "giro", "capital giro", "transmissao", "parque eolico", "implantacao parque", "cana acucar", "energia", "ampliacao capacidade", "objeto leilao", "programa", "credito", "implantacao parque eolico", "desenvolvimento", "tipo", "estaleiro", "embarcacoes", "industriais", "produtos", "lojas", "atividades", "novas", "transporte", "unidades industriais", "cascos", "rebocadores", "ampliacao modernizacao", "embarcacoes tipo", "agua", "terminal", "tecnologia", "shopping", "centro", "pesquisa", "fundo", "destinado", "brasil", "abastecimento", "qualidade", "ambiental", "apoio plano", "serem", "construcao estaleiro", "reforma", "infraestrutura", "realizacao", "meio", "melhoria", "investimentos sociais", "investimentos", "tres", "construcao", "nacional", "rede", "unidades", "modernizacao", "ampliacao", "novos", "empresa", "aquisicao", "paulo", "apoio", "plano", "expansao", "ambito", "sociais", "producao", "implantacao", "sistema", "instalada", "capacidade instalada", "parque", "eolico", "leilao", "objeto", "parque eolico", "implantacao parque", "objeto leilao", "implantacao parque eolico", "complexo", "suplementacao recursos", "potencia", "santa", "total", "aneel", "extensao", "potencia instalada", "leilao energia", "subestacao", "reserva", "eolica", "parques", "ventos", "eolicos", "instalada municipio", "aves", "geradora", "capacidade producao", "objeto leilao energia", "ampliacao capacidade", "central", "localizada municipio", "transmissao", "capacidade", "porto", "suplementacao", "localizada", "fabrica", "implantacao usina", "implantacao", "municipio", "linha", "usina", "producao", "municipios", "recursos", "unidade", "nova", "construcao", "estado", "cana", "acucar", "eletrica", "capital", "giro", "capital giro", "energia eletrica", "cana acucar", "credito", "plantio", "maquinas", "cogeracao", "maquinas equipamentos", "abrangendo", "hectares", "etanol", "plano investimento", "implantacao unidade industrial", "implementacao plano", "moagem", "distribuicao energia", "alcool", "financeiro", "limite", "limite credito", "cogeracao energia", "distribuicao energia eletrica", "formacao", "administracao", "apoio financeiro", "implementacao", "programa", "investimento", "energia", "expansao modernizacao", "distribuicao", "unidade industrial", "implantacao unidade", "unidade", "equipamentos", "expansao", "industrial", "modernizacao", "financiamento", "plano", "investimentos", "apoio", "sistema", "producao"], "Freq": [963.0, 546.0, 455.0, 471.0, 372.0, 336.0, 315.0, 767.0, 743.0, 308.0, 283.0, 315.0, 294.0, 293.0, 270.0, 1200.0, 296.0, 270.0, 254.0, 245.0, 313.0, 250.0, 245.0, 232.0, 508.0, 244.0, 237.0, 471.0, 221.0, 233.0, 471.18134039484795, 314.4815148625668, 296.153039432684, 222.726108644622, 199.65045622501785, 191.54788807341447, 158.953193074886, 153.43483840754845, 145.16597763429564, 143.00321469386913, 133.2115169679472, 128.31098755069144, 130.4205605027536, 131.9155680915896, 125.09183946734429, 165.78583715671908, 130.74023855043217, 123.78978201775847, 120.58149240223018, 184.648780921048, 116.03893366710497, 113.12831060919522, 117.24972065061758, 110.98869064406183, 105.49007785447037, 113.14277382589674, 106.66985683860418, 112.83989591757965, 114.5354834772992, 102.12452761636253, 169.16445330909377, 150.0850388741762, 221.26708980203165, 165.1686169892777, 129.75192683881863, 148.68493754206253, 567.3662076173317, 181.21771225360433, 548.1691588722067, 143.90559984414332, 226.50 ...

# %% [markdown]
# #### WordCloud com as 30 expressões (ngram) mais frequentes por tópico

# %%
# Wordcloud
tf_feature_names_ofna = vectorizer_ofna.get_feature_names()

fig = plt.figure(figsize=(25,20))
for i in range(len(best_lda_model_bs.components_)):
    topic = best_lda_model_bs.components_[i]
    tupleList = [(tf_feature_names_bs[i], int(topic[i]/topic.sum()*10000)) for i in range(len(topic))]
    tupleList.sort(key=itemgetter(1))
    ax = fig.add_subplot(3,3,i+1)
    wordcloud = WordCloud(max_words=30).generate_from_frequencies(dict(tupleList))
    ax.imshow(wordcloud)
    ax.set_title('Tópico n°{}' .format(i))
    ax.axis('off');
